# %% [markdown]
# <a href="https://colab.research.google.com/github/eyalgur1/AutoEncoders/blob/main/AutoEncoder_CNN_PyTorch_experiment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn, optim
from torch.optim import Optimizer
import torchvision
import torchvision.transforms as transforms
import random
import pdb  # for debugging
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Hyperparameters for CIFAR10 training set (set by the user)
# Note: CIFAR10 training set contains 50000 images

batch_size = 125  # batch_size=125 is divisable by 50000 (division is not necessary, but better for plotting)
shuffle = True  # shuffle the training set
seed_base = random.randint(0, 100)  # set seed for reproducibility

# %%
# Hyperparmeters for training of models (set by the user)
# Joint Model: a standard ADAM optimizer model that updates all weights in every iteration.
# NAM Model: updates the encoder and the decoder in an alternating fashion using ADAM.


# Note 1:
# In the current implementation of NAM, the update of the encoder and decoder switches at the end of each epoch.
# This means that after completing an epoch, the next epoch begins with the update of the other one (hence, in a single epoch only one of them is updated).
# This switching strategy can be modified; for instance, they can switch roles within each mini-batch.
# In this alternative approach, the decoder would be trained on a mini-batch, and then the encoder update would switch for the same mini-batch.


# Note 2:
# The implementation of all models below allows to set a maximal number of iterations for the epochs.
# Recall that one iteraion corresponds to a single batch, hence the maximal possible number of iterations at each epoch is len(trainloader.dataset)//batch_size.
# This means that by limiting the number ot iterations for an epochs, implies that not all batches will be considered for this epoch.


num_epochs = 12
num_trials = 10  # number of trials for averaging the loss (over different initializations)
joint_model = True  # Set True for Joint Model training
NAM_model = True  # Set True for NAM Model training
decoder_start = True  # if decoder_start=True, NAM starts with decoder updates, else encoder updates (required for if NAM_model=True); See Note 1 above
lr_joint = 0.001  # lr for Joint Model (set 0.001 for ADAM's default)
lr_decoder, lr_encoder = (0.01, 0.001)  # lr for NAM Model's decoder/encoder update (set 0.001 for ADAM's default)
num_iter_joint = 'max'  # 'max' or inetger lower than 'max' (otherwise it is set automatically to 'max'); limiting the number of iterations of the epochs of the Joint Model; See Note 2 above
num_iter_decoder, num_iter_encoder = ('max', 'max')  # 'max' or inetger lower than 'max' (otherwise it set automatically to 'max'); limiting the number of iterations of the epochs of the NAM Model; See Note 2 above
l1_regul_const = 0.00000001  # l1 regularization constant (here it is used for for sparse encoding)

# %%
# Define an AutoEncoder for 3×32×32 CIFAR10 photos

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        # Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 12, 4, stride=2, padding=1),  # Takes input shape [batch, channel=3, H=32, W=32] and transforms it to [batch, 12, 16, 16]
            nn.ReLU(),
            nn.Conv2d(12, 24, 4, stride=2, padding=1),  # [batch, 24, 8, 8]
            nn.ReLU(),
			nn.Conv2d(24, 48, 4, stride=2, padding=1),  # [batch, 48, 4, 4]
            nn.ReLU(),
        )

        self.decoder = nn.Sequential(
			nn.ConvTranspose2d(48, 24, 4, stride=2, padding=1),  # Takes input shape [batch, channel=48, H=4, W=4] and transforms it to [batch, 12, 16, 16]
            nn.ReLU(),
			nn.ConvTranspose2d(24, 12, 4, stride=2, padding=1),  # [batch, 12, 16, 16]
            nn.ReLU(),
            nn.ConvTranspose2d(12, 3, 4, stride=2, padding=1),  # [batch, 3, 32, 32]
            nn.Sigmoid(),
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        decoded = decoded.view(x.size(0), 3, 32, 32)  # reshape to original image size
        return decoded

# %%
# Auxiliary functions


def set_seed(seed):  # set seed for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)


def switch_requires_grad(model, decoder):  # switch requires_grad for model object containing encoder and decoder
    if decoder:
        for param in model.decoder.parameters():
            param.requires_grad = True
        for param in model.encoder.parameters():
            param.requires_grad = False
    else:
        for param in model.encoder.parameters():
            param.requires_grad = True
        for param in model.decoder.parameters():
            param.requires_grad = False


def reset_learning_rate(optimizer, lr):  # reset learning rate for optimizer object
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
# This function should be redefined to lr annealing.
# This function is currently unused below.


def NAM_epoch_iterations(decoder_update):  # sets the number of iterations for NAM Model epoch
    if decoder_update:  # this is a decoder epoch, so set decoder number of iterations
        num_iter_NAM = num_iter_decoder
    else:  # this is an encoder epoch, so set encoder number of iterations
        num_iter_NAM = num_iter_encoder
    return num_iter_NAM


def check_num_iter(num_iter_joint, num_iter_decoder, num_iter_encoder, num_iter):  # checks and sets the number of iterations for the epochs
    if (num_iter_joint == 'max') or (num_iter_joint > num_iter):
        num_iter_joint = num_iter
    if (num_iter_decoder == 'max') or (num_iter_decoder > num_iter):
        num_iter_decoder = num_iter
    if (num_iter_encoder == 'max') or (num_iter_encoder > num_iter):
        num_iter_encoder = num_iter
    return num_iter_joint, num_iter_decoder, num_iter_encoder


def evaluate_model(model):
    model.eval()
    loss_test = 0
    with torch.no_grad():
        for batch in trainloader:
            inputs, _ = batch
            outputs = model(inputs)
            loss = criterion(outputs, inputs)
            loss_test += loss.item()*inputs.size(0)  # accumulate loss for the test set (multiply by size of batch for taking average over all batches)
    loss_test = loss_test/len(testloader.dataset)
    return loss_test


def l1_regularization(model):  # l1 regularization on the paramters added to the loss (can be applied to any subset of parameters)
    l1_reg = 0
    for param in model.parameters():
        l1_reg += torch.norm(param, p=1)
    return l1_reg
# This function iterates through each parameter tensor and computes the L1 norm of each parameter tensor.
# Since parameters are typically stored in multiple tensors (one for each layer's weights, biases, etc.), a loop is necessary to accumulate the L1 norm across all these tensors.
# This function is currently unused below.


def l1_regularization_output(encoded_output):  # l1 regularization on the outputs added to the loss (can be applied to any subset of outputs)
    return torch.sum(torch.abs(encoded_output))
# Below, this function is applied on the output of the encoder (the encoded images) to make them sparser to be sparse (an not directly on the weights).
# This function will propagate gradients to update the encoder parameters, provided it is included in the loss computation.
# In PyTorch, any operation involving tensors with requires_grad=True will track the gradients.

# %%
# Set training data (CIFAR10)
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transforms.ToTensor())
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transforms.ToTensor())
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=shuffle)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=shuffle)


num_iter = int(len(trainloader.dataset)//batch_size)  # maximum number of iterations per epoch for plotting purposes as it is set automatically by PyTorch)
num_iter_joint, num_iter_decoder, num_iter_encoder = check_num_iter(num_iter_joint, num_iter_decoder, num_iter_encoder, num_iter)  # set the number of iterations for the epochs


# Set loss suitable for autoencoders
criterion = nn.MSELoss()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:10<00:00, 16089957.63it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# Training loop for Joint Model

def joint_model_training(seed):
    set_seed(seed)  # set seed for reproducibility
    model = Autoencoder()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr_joint)  # optimizer for the Joint Model
    loss_val, num_updates, timing, iteration = ({}, {}, {}, 0)  # loss, number of total weight updates per epoch, time of each epoch, total iteration counter (across epochs) for plotting purposes
    total_params = sum(p.numel() for p in model.parameters())  # total number of parameters for the Joint Model

    print(f'\n     Joint Model Training:')

    for epoch in range(num_epochs):
        epoch_loss, epoch_iter, epoch_start = ([], [], time.time())  # loss of epoch iterations, epoch total iteraion counter, start time of each epoch
        for i, batch in enumerate(trainloader):  # for each batch and its index
            if i == num_iter_joint:  # limit the number of iterations of the epochs
                break
            inputs, _ = batch  # get the batch inputs (labels are not required for autoencoders)

            optimizer.zero_grad()  # clear the gradients of all autoencoder parameters

            # calculate loss
            if l1_regul_const > 0: # Add L1 regularization on the encoded outputs to the loss
                encoded_output = model.encoder(inputs)
                decoded_output = model.decoder(encoded_output)
                loss = criterion(decoded_output, inputs) + l1_regul_const * l1_regularization_output(encoded_output)
            else:
                outputs = model(inputs)
                loss = criterion(outputs, inputs)

            loss.backward()  # calculate partial_L/partial_w for all parameters
            optimizer.step()  # update step for all parameters
            epoch_loss.append(loss.item())
            epoch_iter.append(iteration)
            iteration += 1

        # Epoch data collection
        timing[epoch+1] = time.time() - epoch_start  # time of each epoch
        print(f'        Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}, Run time: {timing[epoch+1]:.2f} seconds')
        num_updates[epoch+1] = i * total_params # total weight updates in the epoch (in this model all weights are updates in every batch)
        loss_val[epoch+1] = (epoch_iter, epoch_loss)  # loss in the epoch

    # Evaluate on test set
    loss_test = evaluate_model(model)
    print(f'        Test Loss: {loss_test:.4f}')

    return model, loss_val, num_updates, timing, loss_test

# %%
# Training loop for NAM Model

def NAM_model_training(seed):
    set_seed(seed)  # set seed for reproducibility
    model = Autoencoder()
    optimizer_decoder = torch.optim.Adam(model.decoder.parameters(), lr=lr_decoder)  # decoder optimizer for NAM
    optimizer_encoder = torch.optim.Adam(model.encoder.parameters(), lr=lr_encoder)  # encoder optimizer for NAM
    loss_val, num_updates, timing, iteration = ({}, {}, {}, 0)  # loss, number of total weight updates per epoch, time of each epoch, total iteration counter (across epochs) for plotting purposes
    total_decoder_params = sum(p.numel() for p in model.decoder.parameters())  # total number of decoder parameters
    total_encoder_params = sum(p.numel() for p in model.encoder.parameters())  # total number of encoder parameters

    decoder_update = decoder_start  # switch between encoder and decoder (if decoder_update=Ture, then update decoder, else update encoder)
    num_iter_NAM = NAM_epoch_iterations(decoder_update)  # sets the number of iterations for the first epoch, according to whether the epoch corresponds to decoder/encoder

    # setting requires_grad=False for the non-updated parts could potentially save some computation by avoiding the calculation of gradients for those parameters.
    switch_requires_grad(model, decoder_update)  # switch requires_grad on and off according to the first epoch update (decoder and encoder)

    print(f'\n     NAM Model Training:')

    for epoch in range(num_epochs):
        epoch_loss, epoch_iter, epoch_start = ([], [], time.time())  # loss of epoch iterations, epoch total iteraion counter, start time of each epoch

        for i, data in enumerate(trainloader):  # for each batch and its index
            if i == num_iter_NAM:  # limit the number of iterations of the epochs
                break
            inputs, _ = data  # get the inputs (labels are not required for autoencoders)

            if decoder_update:
                optimizer_decoder.zero_grad()  # clear the gradients of all decoder parameters
            else:
                optimizer_encoder.zero_grad()  # clear the gradients of all encoder parameters

            # calculate loss
            if l1_regul_const > 0: # Add L1 regularization on the encoded outputs to the loss
                encoded_output = model.encoder(inputs)
                decoded_output = model.decoder(encoded_output)
                loss = criterion(decoded_output, inputs) + l1_regul_const * l1_regularization_output(encoded_output)
            else:
                outputs = model(inputs)
                loss = criterion(outputs, inputs)

            loss.backward()  # calculate partial_L/partial_x for all parameters

            if decoder_update:
                optimizer_decoder.step()  # update step for decoder parameters
            else:
                optimizer_encoder.step()  # update step for encoder parameters

            epoch_loss.append(loss.item())
            epoch_iter.append(iteration)
            iteration += 1

        # Epoch data collection
        time_end = time.time() - epoch_start
        if decoder_update:
            timing[epoch+1] = (time_end, 'd')  # time of each epoch
            print(f'        Epoch [{epoch + 1}/{num_epochs}] (decoder), Loss: {loss.item():.4f}, Run time: {time_end:.2f} seconds')
            loss_val[epoch+1] = (epoch_iter, epoch_loss, 'd')
            num_updates[epoch+1] = (i * total_decoder_params, 'd')  # total weight updates in the epoch
        else:
            timing[epoch+1] = (time_end, 'e')  # time of each epoch
            print(f'        Epoch [{epoch + 1}/{num_epochs}] (encoder), Loss: {loss.item():.4f}, Run time: {time_end:.2f} seconds')
            loss_val[epoch+1] = (epoch_iter, epoch_loss, 'e')
            num_updates[epoch+1] = (i * total_encoder_params, 'e')  # total weight updates in the epoch

        decoder_update = not(decoder_update)  # switch between encoder and decoder
        switch_requires_grad(model, decoder_update)  # switch requires_grad on and off according to the next epoch update (decoder and encoder)
        num_iter_NAM = NAM_epoch_iterations(decoder_update)  # sets the number of iterations for the next epoch, according to whether the epoch corresponds to decoder/encoder

    # Evaluate on test set
    loss_test = evaluate_model(model)
    print(f'        Test Loss: {loss_test:.4f}')

    return model, loss_val, num_updates, timing, loss_test

# %%
def average_loss_trials(NAM_model, all_losses):
    if NAM_model:
        avg_loss = {epoch+1: ([], [], all_losses[0][epoch+1][2]) for epoch in range(num_epochs)}  # Initialize avg_loss_NAM based on the encoder/decoder structure of the first trial
    else:
        avg_loss = {epoch+1: ([], []) for epoch in range(num_epochs)}  # Initialize avg_loss_joint
    # Average losses per iteration for each epoch
    for epoch in range(num_epochs):
        total_losses = np.zeros_like(all_losses[0][epoch+1][1])
        for trial in range(num_trials):
            total_losses += np.array(all_losses[trial][epoch+1][1])
        if NAM_model:
            avg_loss[epoch+1] = (all_losses[0][epoch+1][0], total_losses / num_trials, all_losses[0][epoch+1][2])
        else:
            avg_loss[epoch+1] = (all_losses[0][epoch+1][0], total_losses / num_trials)
    return avg_loss


def average_time_trials(NAM_model, all_time):
    if NAM_model:
        avg_time = {epoch+1: ([], all_time[0][epoch+1][1]) for epoch in range(num_epochs)}  # Initialize avg_time_NAM based on
    else:
        avg_time = {epoch+1: [] for epoch in range(num_epochs)}  # Initialize avg_time_joint
    # Average time per iteration for each epoch
    for epoch in range(num_epochs):
        if NAM_model:
            total_time = np.zeros_like(all_time[0][epoch+1][0])
            for trial in range(num_trials):
                total_time += np.array(all_time[trial][epoch+1][0])
            avg_time[epoch+1] = (total_time / num_trials, all_time[0][epoch+1][1])
        else:
            total_time = np.zeros_like(all_time[0][epoch+1])
            for trial in range(num_trials):
                total_time += np.array(all_time[trial][epoch+1])
            avg_time[epoch+1] = total_time / num_trials
    return avg_time


def average_training_trials(seed_base):
    all_joint_losses, all_joint_time, all_joint_test = ([], [], [])
    all_NAM_losses, all_NAM_time, all_NAM_test = ([], [], [])

    # Run multiple trials
    for trial in range(num_trials):
        print(f'\n Trial {trial + 1}/{num_trials}')
        seed = seed_base + trial

        # Joint Model Training
        if joint_model:
            model_joint, loss_joint, param_count_joint, time_joint, loss_test_joint = joint_model_training(seed)
            all_joint_losses.append(loss_joint)
            all_joint_time.append(time_joint)
            all_joint_test.append(loss_test_joint)

        # NAM Model Training
        if NAM_model:
            model_NAM, loss_NAM, param_count_NAM, time_NAM, loss_test_NAM = NAM_model_training(seed)
            all_NAM_losses.append(loss_NAM)
            all_NAM_time.append(time_NAM)
            all_NAM_test.append(loss_test_NAM)

    # Average training loss
    if joint_model:
        avg_loss_joint = average_loss_trials(0, all_joint_losses)
        avg_time_joint = average_time_trials(0, all_joint_time)
    if NAM_model:
        avg_loss_NAM = average_loss_trials(1, all_NAM_losses)
        avg_time_NAM = average_time_trials(1, all_NAM_time)

    # Average test loss
    if joint_model:
        avg_loss_test_joint = np.mean(all_joint_test)
    if NAM_model:
        avg_loss_test_NAM = np.mean(all_NAM_test)

    # Output dictionaries (the returned model is the last trained model)
    if joint_model:
        joint_model_output = {'model':model_joint, 'avg_train_loss':avg_loss_joint, 'avg_param_update': param_count_joint, 'avg_runtime':avg_time_joint, 'avg_test_loss':avg_loss_test_joint}
    else:
        joint_model_output = 'N/A'
    if NAM_model:
        NAM_model_output = {'model':model_NAM, 'avg_train_loss':avg_loss_NAM, 'avg_param_update': param_count_NAM, 'avg_runtime':avg_time_NAM, 'avg_test_loss':avg_loss_test_NAM}
    else:
        NAM_model_output = 'N/A'

    return joint_model_output, NAM_model_output

# %%
# Train and calculate averages over trials (each trial is a different initialization point)
joint_model_output, NAM_model_output = average_training_trials(seed_base)
# Out:
#  Trial 1/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0139, Run time: 28.72 seconds
#         Epoch [2/12], Loss: 0.0088, Run time: 30.42 seconds
#         Epoch [3/12], Loss: 0.0085, Run time: 28.45 seconds
#         Epoch [4/12], Loss: 0.0069, Run time: 28.20 seconds
#         Epoch [5/12], Loss: 0.0059, Run time: 28.64 seconds
#         Epoch [6/12], Loss: 0.0057, Run time: 29.46 seconds
#         Epoch [7/12], Loss: 0.0051, Run time: 28.95 seconds
#         Epoch [8/12], Loss: 0.0050, Run time: 28.51 seconds
#         Epoch [9/12], Loss: 0.0043, Run time: 28.25 seconds
#         Epoch [10/12], Loss: 0.0044, Run time: 29.16 seconds
#         Epoch [11/12], Loss: 0.0046, Run time: 28.31 seconds
#         Epoch [12/12], Loss: 0.0040, Run time: 28.39 seconds
#         Test Loss: 0.0203
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0152, Run time: 22.49 seconds
#         Epoch [2/12] (encoder), Loss: 0.0093, Run time: 25.63 seconds
#         Epoch [3/12] (decoder), Loss: 0.0088, Run time: 23.28 seconds
#         Epoch [4/12] (encoder), Loss: 0.0073, Run time: 25.52 seconds
#         Epoch [5/12] (decoder), Loss: 0.0062, Run time: 23.12 seconds
#         Epoch [6/12] (encoder), Loss: 0.0062, Run time: 25.60 seconds
#         Epoch [7/12] (decoder), Loss: 0.0054, Run time: 23.13 seconds
#         Epoch [8/12] (encoder), Loss: 0.0053, Run time: 26.17 seconds
#         Epoch [9/12] (decoder), Loss: 0.0048, Run time: 24.43 seconds
#         Epoch [10/12] (encoder), Loss: 0.0046, Run time: 25.48 seconds
#         Epoch [11/12] (decoder), Loss: 0.0048, Run time: 23.18 seconds
#         Epoch [12/12] (encoder), Loss: 0.0044, Run time: 25.47 seconds
#         Test Loss: 0.0221
#
#  Trial 2/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0161, Run time: 28.22 seconds
#         Epoch [2/12], Loss: 0.0114, Run time: 29.36 seconds
#         Epoch [3/12], Loss: 0.0090, Run time: 28.32 seconds
#         Epoch [4/12], Loss: 0.0071, Run time: 28.20 seconds
#         Epoch [5/12], Loss: 0.0066, Run time: 28.45 seconds
#         Epoch [6/12], Loss: 0.0058, Run time: 29.45 seconds
#         Epoch [7/12], Loss: 0.0057, Run time: 28.32 seconds
#         Epoch [8/12], Loss: 0.0054, Run time: 28.50 seconds
#         Epoch [9/12], Loss: 0.0050, Run time: 28.58 seconds
#         Epoch [10/12], Loss: 0.0048, Run time: 29.32 seconds
#         Epoch [11/12], Loss: 0.0047, Run time: 28.34 seconds
#         Epoch [12/12], Loss: 0.0049, Run time: 28.44 seconds
#         Test Loss: 0.0225
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0185, Run time: 22.17 seconds
#         Epoch [2/12] (encoder), Loss: 0.0141, Run time: 25.58 seconds
#         Epoch [3/12] (decoder), Loss: 0.0118, Run time: 23.05 seconds
#         Epoch [4/12] (encoder), Loss: 0.0091, Run time: 25.52 seconds
#         Epoch [5/12] (decoder), Loss: 0.0076, Run time: 23.36 seconds
#         Epoch [6/12] (encoder), Loss: 0.0067, Run time: 25.57 seconds
#         Epoch [7/12] (decoder), Loss: 0.0063, Run time: 23.39 seconds
#         Epoch [8/12] (encoder), Loss: 0.0060, Run time: 25.54 seconds
#         Epoch [9/12] (decoder), Loss: 0.0054, Run time: 23.18 seconds
#         Epoch [10/12] (encoder), Loss: 0.0052, Run time: 25.55 seconds
#         Epoch [11/12] (decoder), Loss: 0.0051, Run time: 23.25 seconds
#         Epoch [12/12] (encoder), Loss: 0.0055, Run time: 25.58 seconds
#         Test Loss: 0.0263
#
#  Trial 3/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0155, Run time: 28.04 seconds
#         Epoch [2/12], Loss: 0.0110, Run time: 28.59 seconds
#         Epoch [3/12], Loss: 0.0084, Run time: 28.79 seconds
#         Epoch [4/12], Loss: 0.0068, Run time: 28.74 seconds
#         Epoch [5/12], Loss: 0.0064, Run time: 28.29 seconds
#         Epoch [6/12], Loss: 0.0062, Run time: 29.47 seconds
#         Epoch [7/12], Loss: 0.0060, Run time: 28.26 seconds
#         Epoch [8/12], Loss: 0.0057, Run time: 28.17 seconds
#         Epoch [9/12], Loss: 0.0051, Run time: 28.32 seconds
#         Epoch [10/12], Loss: 0.0045, Run time: 29.27 seconds
#         Epoch [11/12], Loss: 0.0042, Run time: 28.54 seconds
#         Epoch [12/12], Loss: 0.0041, Run time: 28.14 seconds
#         Test Loss: 0.0184
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0188, Run time: 23.00 seconds
#         Epoch [2/12] (encoder), Loss: 0.0133, Run time: 25.42 seconds
#         Epoch [3/12] (decoder), Loss: 0.0089, Run time: 23.08 seconds
#         Epoch [4/12] (encoder), Loss: 0.0076, Run time: 25.63 seconds
#         Epoch [5/12] (decoder), Loss: 0.0070, Run time: 23.05 seconds
#         Epoch [6/12] (encoder), Loss: 0.0068, Run time: 25.34 seconds
#         Epoch [7/12] (decoder), Loss: 0.0064, Run time: 23.22 seconds
#         Epoch [8/12] (encoder), Loss: 0.0058, Run time: 25.44 seconds
#         Epoch [9/12] (decoder), Loss: 0.0054, Run time: 22.73 seconds
#         Epoch [10/12] (encoder), Loss: 0.0051, Run time: 25.47 seconds
#         Epoch [11/12] (decoder), Loss: 0.0050, Run time: 22.54 seconds
#         Epoch [12/12] (encoder), Loss: 0.0046, Run time: 25.38 seconds
#         Test Loss: 0.0224
#
#  Trial 4/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0114, Run time: 28.12 seconds
#         Epoch [2/12], Loss: 0.0083, Run time: 28.06 seconds
#         Epoch [3/12], Loss: 0.0075, Run time: 28.10 seconds
#         Epoch [4/12], Loss: 0.0061, Run time: 29.25 seconds
#         Epoch [5/12], Loss: 0.0063, Run time: 28.49 seconds
#         Epoch [6/12], Loss: 0.0055, Run time: 28.67 seconds
#         Epoch [7/12], Loss: 0.0049, Run time: 28.98 seconds
#         Epoch [8/12], Loss: 0.0044, Run time: 28.66 seconds
#         Epoch [9/12], Loss: 0.0043, Run time: 28.34 seconds
#         Epoch [10/12], Loss: 0.0043, Run time: 28.27 seconds
#         Epoch [11/12], Loss: 0.0038, Run time: 29.04 seconds
#         Epoch [12/12], Loss: 0.0039, Run time: 28.65 seconds
#         Test Loss: 0.0178
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0156, Run time: 23.22 seconds
#         Epoch [2/12] (encoder), Loss: 0.0104, Run time: 25.57 seconds
#         Epoch [3/12] (decoder), Loss: 0.0082, Run time: 23.11 seconds
#         Epoch [4/12] (encoder), Loss: 0.0068, Run time: 25.47 seconds
#         Epoch [5/12] (decoder), Loss: 0.0068, Run time: 23.17 seconds
#         Epoch [6/12] (encoder), Loss: 0.0060, Run time: 25.48 seconds
#         Epoch [7/12] (decoder), Loss: 0.0050, Run time: 23.04 seconds
#         Epoch [8/12] (encoder), Loss: 0.0047, Run time: 25.62 seconds
#         Epoch [9/12] (decoder), Loss: 0.0044, Run time: 22.27 seconds
#         Epoch [10/12] (encoder), Loss: 0.0045, Run time: 25.43 seconds
#         Epoch [11/12] (decoder), Loss: 0.0039, Run time: 23.06 seconds
#         Epoch [12/12] (encoder), Loss: 0.0042, Run time: 25.63 seconds
#         Test Loss: 0.0225
#
#  Trial 5/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0137, Run time: 28.32 seconds
#         Epoch [2/12], Loss: 0.0086, Run time: 28.25 seconds
#         Epoch [3/12], Loss: 0.0070, Run time: 28.31 seconds
#         Epoch [4/12], Loss: 0.0065, Run time: 29.18 seconds
#         Epoch [5/12], Loss: 0.0055, Run time: 28.41 seconds
#         Epoch [6/12], Loss: 0.0049, Run time: 28.30 seconds
#         Epoch [7/12], Loss: 0.0046, Run time: 28.42 seconds
#         Epoch [8/12], Loss: 0.0044, Run time: 29.34 seconds
#         Epoch [9/12], Loss: 0.0043, Run time: 28.29 seconds
#         Epoch [10/12], Loss: 0.0041, Run time: 28.18 seconds
#         Epoch [11/12], Loss: 0.0047, Run time: 28.25 seconds
#         Epoch [12/12], Loss: 0.0037, Run time: 29.06 seconds
#         Test Loss: 0.0169
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0135, Run time: 23.18 seconds
#         Epoch [2/12] (encoder), Loss: 0.0081, Run time: 25.45 seconds
#         Epoch [3/12] (decoder), Loss: 0.0070, Run time: 23.24 seconds
#         Epoch [4/12] (encoder), Loss: 0.0066, Run time: 25.62 seconds
#         Epoch [5/12] (decoder), Loss: 0.0061, Run time: 22.21 seconds
#         Epoch [6/12] (encoder), Loss: 0.0051, Run time: 25.48 seconds
#         Epoch [7/12] (decoder), Loss: 0.0045, Run time: 23.00 seconds
#         Epoch [8/12] (encoder), Loss: 0.0047, Run time: 25.47 seconds
#         Epoch [9/12] (decoder), Loss: 0.0043, Run time: 23.01 seconds
#         Epoch [10/12] (encoder), Loss: 0.0041, Run time: 25.36 seconds
#         Epoch [11/12] (decoder), Loss: 0.0039, Run time: 22.95 seconds
#         Epoch [12/12] (encoder), Loss: 0.0040, Run time: 25.34 seconds
#         Test Loss: 0.0188
#
#  Trial 6/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0103, Run time: 28.21 seconds
#         Epoch [2/12], Loss: 0.0081, Run time: 28.82 seconds
#         Epoch [3/12], Loss: 0.0069, Run time: 28.01 seconds
#         Epoch [4/12], Loss: 0.0062, Run time: 28.10 seconds
#         Epoch [5/12], Loss: 0.0065, Run time: 28.15 seconds
#         Epoch [6/12], Loss: 0.0048, Run time: 29.15 seconds
#         Epoch [7/12], Loss: 0.0047, Run time: 28.18 seconds
#         Epoch [8/12], Loss: 0.0043, Run time: 28.11 seconds
#         Epoch [9/12], Loss: 0.0043, Run time: 28.16 seconds
#         Epoch [10/12], Loss: 0.0041, Run time: 29.05 seconds
#         Epoch [11/12], Loss: 0.0038, Run time: 28.21 seconds
#         Epoch [12/12], Loss: 0.0035, Run time: 28.30 seconds
#         Test Loss: 0.0173
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0142, Run time: 22.44 seconds
#         Epoch [2/12] (encoder), Loss: 0.0092, Run time: 25.52 seconds
#         Epoch [3/12] (decoder), Loss: 0.0076, Run time: 23.03 seconds
#         Epoch [4/12] (encoder), Loss: 0.0066, Run time: 25.52 seconds
#         Epoch [5/12] (decoder), Loss: 0.0058, Run time: 23.20 seconds
#         Epoch [6/12] (encoder), Loss: 0.0055, Run time: 25.43 seconds
#         Epoch [7/12] (decoder), Loss: 0.0053, Run time: 23.13 seconds
#         Epoch [8/12] (encoder), Loss: 0.0050, Run time: 25.47 seconds
#         Epoch [9/12] (decoder), Loss: 0.0054, Run time: 23.10 seconds
#         Epoch [10/12] (encoder), Loss: 0.0048, Run time: 25.45 seconds
#         Epoch [11/12] (decoder), Loss: 0.0041, Run time: 22.56 seconds
#         Epoch [12/12] (encoder), Loss: 0.0038, Run time: 25.37 seconds
#         Test Loss: 0.0204
#
#  Trial 7/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0132, Run time: 28.18 seconds
#         Epoch [2/12], Loss: 0.0088, Run time: 28.20 seconds
#         Epoch [3/12], Loss: 0.0073, Run time: 29.34 seconds
#         Epoch [4/12], Loss: 0.0065, Run time: 28.22 seconds
#         Epoch [5/12], Loss: 0.0064, Run time: 28.26 seconds
#         Epoch [6/12], Loss: 0.0049, Run time: 28.28 seconds
#         Epoch [7/12], Loss: 0.0045, Run time: 29.17 seconds
#         Epoch [8/12], Loss: 0.0048, Run time: 28.37 seconds
#         Epoch [9/12], Loss: 0.0041, Run time: 28.17 seconds
#         Epoch [10/12], Loss: 0.0040, Run time: 28.18 seconds
#         Epoch [11/12], Loss: 0.0042, Run time: 29.16 seconds
#         Epoch [12/12], Loss: 0.0036, Run time: 28.39 seconds
#         Test Loss: 0.0170
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0186, Run time: 23.18 seconds
#         Epoch [2/12] (encoder), Loss: 0.0115, Run time: 25.52 seconds
#         Epoch [3/12] (decoder), Loss: 0.0106, Run time: 23.14 seconds
#         Epoch [4/12] (encoder), Loss: 0.0089, Run time: 25.55 seconds
#         Epoch [5/12] (decoder), Loss: 0.0075, Run time: 23.12 seconds
#         Epoch [6/12] (encoder), Loss: 0.0057, Run time: 25.49 seconds
#         Epoch [7/12] (decoder), Loss: 0.0059, Run time: 23.05 seconds
#         Epoch [8/12] (encoder), Loss: 0.0062, Run time: 25.58 seconds
#         Epoch [9/12] (decoder), Loss: 0.0052, Run time: 22.30 seconds
#         Epoch [10/12] (encoder), Loss: 0.0052, Run time: 25.58 seconds
#         Epoch [11/12] (decoder), Loss: 0.0054, Run time: 23.36 seconds
#         Epoch [12/12] (encoder), Loss: 0.0045, Run time: 25.60 seconds
#         Test Loss: 0.0229
#
#  Trial 8/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0128, Run time: 28.21 seconds
#         Epoch [2/12], Loss: 0.0088, Run time: 28.28 seconds
#         Epoch [3/12], Loss: 0.0076, Run time: 28.36 seconds
#         Epoch [4/12], Loss: 0.0068, Run time: 29.38 seconds
#         Epoch [5/12], Loss: 0.0057, Run time: 28.30 seconds
#         Epoch [6/12], Loss: 0.0052, Run time: 28.28 seconds
#         Epoch [7/12], Loss: 0.0048, Run time: 28.32 seconds
#         Epoch [8/12], Loss: 0.0044, Run time: 29.38 seconds
#         Epoch [9/12], Loss: 0.0040, Run time: 28.23 seconds
#         Epoch [10/12], Loss: 0.0041, Run time: 28.40 seconds
#         Epoch [11/12], Loss: 0.0037, Run time: 28.53 seconds
#         Epoch [12/12], Loss: 0.0038, Run time: 29.18 seconds
#         Test Loss: 0.0178
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0131, Run time: 23.05 seconds
#         Epoch [2/12] (encoder), Loss: 0.0083, Run time: 25.59 seconds
#         Epoch [3/12] (decoder), Loss: 0.0075, Run time: 23.25 seconds
#         Epoch [4/12] (encoder), Loss: 0.0068, Run time: 25.52 seconds
#         Epoch [5/12] (decoder), Loss: 0.0056, Run time: 22.97 seconds
#         Epoch [6/12] (encoder), Loss: 0.0053, Run time: 25.54 seconds
#         Epoch [7/12] (decoder), Loss: 0.0048, Run time: 22.29 seconds
#         Epoch [8/12] (encoder), Loss: 0.0046, Run time: 25.57 seconds
#         Epoch [9/12] (decoder), Loss: 0.0038, Run time: 23.33 seconds
#         Epoch [10/12] (encoder), Loss: 0.0043, Run time: 25.59 seconds
#         Epoch [11/12] (decoder), Loss: 0.0039, Run time: 23.08 seconds
#         Epoch [12/12] (encoder), Loss: 0.0035, Run time: 25.50 seconds
#         Test Loss: 0.0191
#
#  Trial 9/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0141, Run time: 29.21 seconds
#         Epoch [2/12], Loss: 0.0090, Run time: 28.33 seconds
#         Epoch [3/12], Loss: 0.0069, Run time: 28.36 seconds
#         Epoch [4/12], Loss: 0.0068, Run time: 28.64 seconds
#         Epoch [5/12], Loss: 0.0056, Run time: 29.04 seconds
#         Epoch [6/12], Loss: 0.0055, Run time: 28.28 seconds
#         Epoch [7/12], Loss: 0.0053, Run time: 28.47 seconds
#         Epoch [8/12], Loss: 0.0046, Run time: 28.69 seconds
#         Epoch [9/12], Loss: 0.0047, Run time: 28.76 seconds
#         Epoch [10/12], Loss: 0.0048, Run time: 28.29 seconds
#         Epoch [11/12], Loss: 0.0044, Run time: 28.55 seconds
#         Epoch [12/12], Loss: 0.0037, Run time: 29.27 seconds
#         Test Loss: 0.0176
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0124, Run time: 23.61 seconds
#         Epoch [2/12] (encoder), Loss: 0.0082, Run time: 25.97 seconds
#         Epoch [3/12] (decoder), Loss: 0.0064, Run time: 23.49 seconds
#         Epoch [4/12] (encoder), Loss: 0.0059, Run time: 25.97 seconds
#         Epoch [5/12] (decoder), Loss: 0.0049, Run time: 23.43 seconds
#         Epoch [6/12] (encoder), Loss: 0.0048, Run time: 26.20 seconds
#         Epoch [7/12] (decoder), Loss: 0.0045, Run time: 22.82 seconds
#         Epoch [8/12] (encoder), Loss: 0.0043, Run time: 26.02 seconds
#         Epoch [9/12] (decoder), Loss: 0.0039, Run time: 23.18 seconds
#         Epoch [10/12] (encoder), Loss: 0.0036, Run time: 26.00 seconds
#         Epoch [11/12] (decoder), Loss: 0.0039, Run time: 23.25 seconds
#         Epoch [12/12] (encoder), Loss: 0.0034, Run time: 25.66 seconds
#         Test Loss: 0.0167
#
#  Trial 10/10
#
#      Joint Model Training:
#         Epoch [1/12], Loss: 0.0146, Run time: 28.50 seconds
#         Epoch [2/12], Loss: 0.0095, Run time: 28.35 seconds
#         Epoch [3/12], Loss: 0.0074, Run time: 28.60 seconds
#         Epoch [4/12], Loss: 0.0069, Run time: 29.28 seconds
#         Epoch [5/12], Loss: 0.0065, Run time: 28.35 seconds
#         Epoch [6/12], Loss: 0.0057, Run time: 28.57 seconds
#         Epoch [7/12], Loss: 0.0054, Run time: 28.93 seconds
#         Epoch [8/12], Loss: 0.0053, Run time: 28.98 seconds
#         Epoch [9/12], Loss: 0.0047, Run time: 28.52 seconds
#         Epoch [10/12], Loss: 0.0050, Run time: 28.36 seconds
#         Epoch [11/12], Loss: 0.0044, Run time: 29.34 seconds
#         Epoch [12/12], Loss: 0.0046, Run time: 28.48 seconds
#         Test Loss: 0.0202
#
#      NAM Model Training:
#         Epoch [1/12] (decoder), Loss: 0.0158, Run time: 23.24 seconds
#         Epoch [2/12] (encoder), Loss: 0.0098, Run time: 25.68 seconds
#         Epoch [3/12] (decoder), Loss: 0.0081, Run time: 23.10 seconds
#         Epoch [4/12] (encoder), Loss: 0.0076, Run time: 25.63 seconds
#         Epoch [5/12] (decoder), Loss: 0.0070, Run time: 23.31 seconds
#         Epoch [6/12] (encoder), Loss: 0.0058, Run time: 25.65 seconds
#         Epoch [7/12] (decoder), Loss: 0.0056, Run time: 23.45 seconds
#         Epoch [8/12] (encoder), Loss: 0.0053, Run time: 25.79 seconds
#         Epoch [9/12] (decoder), Loss: 0.0046, Run time: 22.35 seconds
#         Epoch [10/12] (encoder), Loss: 0.0053, Run time: 25.56 seconds
#         Epoch [11/12] (decoder), Loss: 0.0043, Run time: 23.06 seconds
#         Epoch [12/12] (encoder), Loss: 0.0046, Run time: 25.73 seconds
#         Test Loss: 0.0203

# %%
plot_joint_model = True
plot_NAM_model = True


if plot_joint_model:
    param_count_joint = joint_model_output['avg_param_update']
    avg_loss_joint = joint_model_output['avg_train_loss']
    avg_loss_test_joint = joint_model_output['avg_test_loss']
    avg_time_joint = joint_model_output['avg_runtime']
if plot_NAM_model:
    param_count_NAM = NAM_model_output['avg_param_update']
    avg_loss_NAM = NAM_model_output['avg_train_loss']
    avg_loss_test_NAM = NAM_model_output['avg_test_loss']
    avg_time_NAM = NAM_model_output['avg_runtime']


# Calculate number of decoder and decoder epochs for later average calculations
if plot_NAM_model:
    num_decoder_epochs = sum([1 if param_count_NAM[epoch+1][1]=='d' else 0 for epoch in range(num_epochs)])
    num_encoder_epochs = sum([1 if param_count_NAM[epoch+1][1]=='e' else 0 for epoch in range(num_epochs)])
    if num_decoder_epochs > 0:
        inv_num_decoder_epochs = 1/num_decoder_epochs
    else:
        inv_num_decoder_epochs = np.nan
    if num_encoder_epochs > 0:
        inv_num_encoder_epochs = 1/num_encoder_epochs
    else:
        inv_num_encoder_epochs = np.nan


# Plotting the Training Loss
if plot_joint_model:
    for epoch in range(num_epochs):
        plt.semilogy(avg_loss_joint[epoch+1][0], avg_loss_joint[epoch+1][1], color='green', linewidth=0.5)


if plot_NAM_model:
    for epoch in range(num_epochs):
        if avg_loss_NAM[epoch+1][2] == 'd':  # plot decoder iteration segments
            plt.plot(avg_loss_NAM[epoch+1][0], avg_loss_NAM[epoch+1][1], color='blue', linewidth = 0.5)
        else:  # plot encoder iteration segments
            plt.plot(avg_loss_NAM[epoch+1][0], avg_loss_NAM[epoch+1][1], color='red', linewidth = 0.5)


plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Average Training Loss Over Trails (Initializations)')
plt.xlim([0, num_epochs*num_iter])
plt.legend(['Joint Model', 'NAM (decoder)', 'NAM (encoder)'])
plt.show()


# Average total number of weight updates
print('\n')
print(f'Average total weight updates per epoch over trials:')
if plot_joint_model:
    avg_joint_updates = (1/num_epochs)*sum(param_count_joint[epoch+1] for epoch in range(num_epochs))
    print(f'    Joint Model:', avg_joint_updates)

    avg_decoder_updates = inv_num_decoder_epochs*sum(param_count_NAM[epoch+1][0] if param_count_NAM[epoch+1][1]=='d' else 0 for epoch in range(num_epochs))
    avg_encoder_updates = inv_num_encoder_epochs*sum(param_count_NAM[epoch+1][0] if param_count_NAM[epoch+1][1]=='e' else 0 for epoch in range(num_epochs))
    print(f'    NAM Model (decoder):', avg_decoder_updates)
    print(f'    NAM Model (encoder):', avg_encoder_updates)
    avg_NAM_updates = np.nanmean([avg_decoder_updates, avg_encoder_updates])
    print(f'    NAM Model (decoder and encoder):', avg_NAM_updates)
if plot_joint_model and plot_NAM_model:
    print(f'    The Joint Model updates {avg_joint_updates/avg_NAM_updates:.2f} times more weights per epoch compared to the NAM Model')


# Average run time per epoch for each model
print('\n')
print(f'Average run time per epoch over trials:')
if plot_joint_model:
    avg_joint_time = (1/num_epochs)*sum(avg_time_joint[epoch+1] for epoch in range(num_epochs))
    print(f'    Joint Model: {avg_joint_time:.2f} seconds')
if NAM_model:
    avg_decoder_time = inv_num_decoder_epochs*sum(avg_time_NAM[epoch+1][0] if avg_time_NAM[epoch+1][1]=='d' else 0 for epoch in range(num_epochs))
    avg_encoder_time = inv_num_encoder_epochs*sum(avg_time_NAM[epoch+1][0] if avg_time_NAM[epoch+1][1]=='e' else 0 for epoch in range(num_epochs))
    print(f'    NAM Model (decoder): {avg_decoder_time:.2f} seconds')
    print(f'    NAM Model (encoder): {avg_encoder_time:.2f} seconds')
    avg_NAM_time = np.nanmean([avg_decoder_time, avg_encoder_time])
    print(f'    NAM Model (decoder and encoder): {avg_NAM_time:.2f} seconds')
if plot_joint_model and plot_NAM_model:
    print(f'    The NAM Model is {(1-avg_NAM_time/avg_joint_time)*100:.2f}% faster than the Joint Model')

# Average test loss
print('\n')
print(f'Average test loss over trials:')
print(f'    Joint Model: {avg_loss_test_joint:.4f}')
print(f'    NAM Model: {avg_loss_test_NAM:.4f}')
# Out:
# Average total weight updates per epoch over trials:
#     Joint Model: 18894645.0
#     NAM Model (decoder): 9438345.0
#     NAM Model (encoder): 9456300.0
#     NAM Model (decoder and encoder): 9447322.5
#     The Joint Model updates 2.00 times more weights per epoch compared to the NAM Model
#
#
# Average run time per epoch over trials:
#     Joint Model: 28.58 seconds
#     NAM Model (decoder): 23.05 seconds
#     NAM Model (encoder): 25.58 seconds
#     NAM Model (decoder and encoder): 24.32 seconds
#     The NAM Model is 14.92% faster than the Joint Model
#
#
# Average test loss over trials:
#     Joint Model: 0.0186
#     NAM Model: 0.0212

# %%
def display_images(original_images, joint_decoded_images, nam_decoded_images, num_images = 10):
    fig, ax = plt.subplots(num_images, 3, figsize=(6, num_images*2))
    for i in range(num_images):
        # Plot images
        ax[i, 0].imshow(np.transpose(original_images[i], (1, 2, 0)))  # original images (left column)
        ax[i, 0].set_xticks([]); ax[i, 0].set_yticks([])  # remove ticks but keep option for label
        ax[i, 1].imshow(np.transpose(joint_decoded_images[i], (1, 2, 0)))  # joint model images (middle column)
        ax[i, 1].set_xticks([]); ax[i, 1].set_yticks([])  # remove ticks but keep option for label
        ax[i, 2].imshow(np.transpose(nam_decoded_images[i], (1, 2, 0)))  # NAM model images (right column)
        ax[i, 2].set_xticks([]); ax[i, 2].set_yticks([])  # remove ticks but keep option for label

    ax[0, 0].set_title('Original', size='large')
    ax[0, 1].set_title('Joint Model', size='large')
    ax[0, 2].set_title('NAM Model', size='large')
    plt.show()

# Get num_images random images from the testloader
num_images = 10
small_testloader = torch.utils.data.DataLoader(testset, batch_size=num_images, shuffle=True, num_workers=2)
test_images, _ = next(iter(small_testloader))

# Encode and decode with the joint model
last_model_joint = joint_model_output['model']
last_model_joint.eval()
with torch.no_grad():
    joint_decoded_images = last_model_joint(test_images).cpu().numpy()

# Encode and decode with the NAM model
last_model_NAM = NAM_model_output['model']
last_model_NAM.eval()
with torch.no_grad():
    nam_decoded_images = last_model_NAM(test_images).cpu().numpy()

# Display the images
display_images(test_images.cpu().numpy(), joint_decoded_images, nam_decoded_images, num_images)

# %%
# Compression rate
original_l1 = torch.norm(test_images, p=1)/len(test_images)
joint_l1 = torch.norm(last_model_joint.encoder(test_images))/len(test_images)
nam_l1 = torch.norm(last_model_NAM.encoder(test_images))/len(test_images)
print(f'Average L1-norm for', num_images, 'random images:')
print(f'    Original images: {original_l1:.2f}')
print(f'    Joint Model (encodings of last obtained model): {joint_l1:.2f}')
print(f'    NAM Model (encodings of last obtained model): {nam_l1:.2f}')
print('')
print(f'    Estimated average compression rate:')
print(f'        Joint Model: {original_l1/joint_l1:.2f}')
print(f'        NAM Model: {original_l1/nam_l1:.2f}')
print(f'        NAM compresses {joint_l1/nam_l1:.2f} times more than the Joint Model')
# Out:
# Average L1-norm for 10 random images:
#     Original images: 1415.94
#     Joint Model (last obtained model): 3.59
#     NAM Model (last obtained model): 0.55
#
#     Estimated average compression rate:
#         Joint Model: 394.03
#         NAM Model: 2586.97
#         NAM compresses 6.57 times more than the Joint Model
